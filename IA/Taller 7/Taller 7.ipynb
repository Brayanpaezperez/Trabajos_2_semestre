# %% [markdown]
# # **Taller 7**
#
# ## **Inteligencia Artificial**
#
# ### **Maestría en Analítica de Datos**
#
# **Facultad de Ingeniería y Ciencias Básicas.**
#
# **Universidad Central**
#
# > **Integrantes:**
#
# >>***1. Brayan Holman Paez Perez***
#
# >>***2. Michel Esteven Céspedes Medina***
#
#
# > **Profesor:**
#
# >>***Hugo Franco***

# %%
from taller_7_ap  import *
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Lectura de archivos

# %%
nombre_columnas = ['Embarazos', 'Glucosa', 'Presion Arterial', 'Grosor Piel', 'Insulina', 'Indice Masa Corporal', 'Función de Pedigree', 'Edad', 'Etiqueta']
url_carpeta='C:/Users/Bluetab/Documents/Universidad/Archivos 2doSemestre/IA/'
iris=pd.read_csv(url_carpeta+'iris.csv')
diabetes=pd.read_csv(url_carpeta+'diabetes.csv', header=1, names=nombre_columnas)
dataset1=pd.read_csv(url_carpeta+'dataset_1.csv',sep=';',header=None)
dataset2=pd.read_csv(url_carpeta+'dataset_2.csv',sep=';',header=None)
dataset1.columns=['x','y','z']
dataset2.columns=['x','y','z']

# %% [markdown]
# # 1.  Aprendizaje no supervisado:
# ## a. Use los métodos de clustering vistos en clase (K-means, DBSCAN, Mezcla de Gaussianas) sobre los datasets disponibles en el sitio web del curso, usando las dos  primeras columnas como características. Determine el mejor K para los métodos de K-means y mezcla de gaussianas.
#
# ## b.  Use la tercera columna de los datasets, junto con la inspección visual de los resultados del “clustering”, para evaluar el desempeño de cada método.

# %% [markdown]
# ## K-means

# %%
k_means(iris.SepalLengthCm,iris.SepalWidthCm,iris.PetalLengthCm	)
# Out:
# Cluster 1 Función de costo 594.0446666666667
# Cluster 2 Función de costo 133.4571484147053
# Cluster 3 Función de costo 69.5001392446634
# Cluster 4 Función de costo 49.50821558441557
# Cluster 5 Función de costo 40.52383908045979
# Cluster 6 Función de costo 33.0374925426176
# Cluster 7 Función de costo 29.211478937728938

# %%
k_means(diabetes.Embarazos,diabetes.Glucosa,diabetes.Etiqueta)
# Out:
# Cluster 1 Función de costo 792206.7588005234
# Cluster 2 Función de costo 290276.0279458415
# Cluster 3 Función de costo 160491.9548299452
# Cluster 4 Función de costo 109583.4074444722
# Cluster 5 Función de costo 74452.3642708385
# Cluster 6 Función de costo 50694.39983375569
# Cluster 7 Función de costo 39687.51327143843

# %%
k_means(dataset1.x,dataset1.y,dataset1.z)
# Out:
# Cluster 1 Función de costo 130986.77907994931
# Cluster 2 Función de costo 69905.29945266023
# Cluster 3 Función de costo 35990.0723768543
# Cluster 4 Función de costo 24495.045163759518
# Cluster 5 Función de costo 17418.296865198907
# Cluster 6 Función de costo 12975.794743968681
# Cluster 7 Función de costo 11108.989964800496

# %%
k_means(dataset2.x,dataset2.y,dataset2.z)
# Out:
# Cluster 1 Función de costo 47682.48414786963
# Cluster 2 Función de costo 13189.733245533502
# Cluster 3 Función de costo 7800.205668497206
# Cluster 4 Función de costo 6406.126475198803
# Cluster 5 Función de costo 5034.210212678662
# Cluster 6 Función de costo 3929.046937233848
# Cluster 7 Función de costo 3350.020856511127

# %% [markdown]
# ##  DBSCAN

# %%
dbscan_(iris.SepalLengthCm,iris.SepalWidthCm,iris.PetalLengthCm	)

# %%
dbscan_(diabetes.Embarazos,diabetes.Glucosa,diabetes.Etiqueta)

# %%
dbscan_(dataset1.x,dataset1.y,dataset1.z)

# %%
dbscan_(dataset2.x,dataset2.y,dataset2.z)

# %% [markdown]
# ## Mezcla De Gaussianas

# %%
m_gauss(iris.SepalLengthCm,iris.SepalWidthCm,iris.PetalLengthCm	)
# Out:
# Clasificación no-supervisada mediante mezcla de gaussianas
# Etiqueta original, de la generación de los datos aleatorios

# %%
m_gauss(diabetes.Embarazos,diabetes.Glucosa,diabetes.Etiqueta)
# Out:
# Clasificación no-supervisada mediante mezcla de gaussianas
# Etiqueta original, de la generación de los datos aleatorios

# %%
m_gauss(dataset1.x,dataset1.y,dataset1.z)
# Out:
# Clasificación no-supervisada mediante mezcla de gaussianas
# Etiqueta original, de la generación de los datos aleatorios

# %%
m_gauss(dataset2.x,dataset2.y,dataset2.z)
# Out:
# Clasificación no-supervisada mediante mezcla de gaussianas
# Etiqueta original, de la generación de los datos aleatorios

# %% [markdown]
# # 2.  Aprendizaje supervisado:
# ## a.  Sesiones prácticas: usar los tres métodos vistos en clase (KNN, Árboles de decisión y SVC) para entrenar modelos que permitan llevar a cabo la clasificación de elementos de los tres datesets empleados (Iris, Diabetes en la India, Descriptores de imágenes de histología en cáncer de mama - U. de Wisconsin)
#
# ## b.  Discusión: usar las métricas vistas en clase para la evaluación del desempeño (en entrenamiento y prueba) de cada modelo en cada problema y comparar los resultados obtenidos.
#
# ## c.  Investigación: usar un modelo de clasificación de tipo “random forest” (ensemble) para los mismos problemas. Incluir sus resultados en el análisis comparativo de los modelos de clasificación evaluados.

# %% [markdown]
# ## KNN

# %%
k_nn(iris[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']],iris['Species'],list(iris['Species'].unique()))
# Out:
# Tamaño de X_train: (112, 4)
# Tamaño de y_train: (112,)
# Tamaño de X_test: (38, 4)
# Tamaño de y_test: (38,)
# Score sobre el conjunto de test: 1.000
# [1.   0.88 1.   1.   0.86]
# Promedio
# 0.9464285714285714
# Exactitud (accuracy) en prueba (testing): 0.9736842105263158

# %%
k_nn(diabetes.drop('Etiqueta',axis=1),diabetes['Etiqueta'],list(diabetes['Etiqueta'].unique()))
# Out:
# Tamaño de X_train: (575, 8)
# Tamaño de y_train: (575,)
# Tamaño de X_test: (192, 8)
# Tamaño de y_test: (192,)
# Score sobre el conjunto de test: 1.000
# [0.69 0.69 0.68 0.66 0.68]
# Promedio
# 0.6821862348178137
# Exactitud (accuracy) en prueba (testing): 0.6822916666666666

# %%
k_nn(dataset1[['x','y']],dataset1['z'],list(dataset1['z'].unique()))
# Out:
# Tamaño de X_train: (591, 2)
# Tamaño de y_train: (591,)
# Tamaño de X_test: (197, 2)
# Tamaño de y_test: (197,)
# Score sobre el conjunto de test: 1.000
# [1.   1.   1.   0.97 1.  ]
# Promedio
# 0.9948717948717949
# Exactitud (accuracy) en prueba (testing): 1.0

# %%
k_nn(dataset2[['x','y']],dataset2['z'],list(dataset2['z'].unique()))
# Out:
# Tamaño de X_train: (299, 2)
# Tamaño de y_train: (299,)
# Tamaño de X_test: (100, 2)
# Tamaño de y_test: (100,)
# Score sobre el conjunto de test: 1.000
# [1.  1.  0.9 1.  1. ]
# Promedio
# 0.9800000000000001
# Exactitud (accuracy) en prueba (testing): 0.96

# %% [markdown]
# ## Arboles de decision

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

# %%
graph=tree_desc(iris[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']],iris['Species'],['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],list(iris['Species'].unique()))
graph.write_png('iris.png')
Image(graph.create_png())
# Out:
# Tamaño de X_train: (105, 4)
# Tamaño de y_train: (105,)
# Tamaño de X_test: (45, 4)
# Tamaño de y_test: (45,)
# [1.   0.95 1.   0.95 0.86]
# 0.9523809523809523
# Exactitud (accuracy): 0.9555555555555556

# %%
graph=tree_desc(diabetes.drop('Etiqueta',axis=1),diabetes['Etiqueta'],['Embarazos', 'Glucosa', 'Presion Arterial', 'Grosor Piel', 'Insulina',
       'Indice Masa Corporal', 'Función de Pedigree', 'Edad'],list(diabetes['Etiqueta'].unique()))
graph.write_png('diabetes.png')
Image(graph.create_png())
# Out:
# Tamaño de X_train: (536, 8)
# Tamaño de y_train: (536,)
# Tamaño de X_test: (231, 8)
# Tamaño de y_test: (231,)
# [0.7  0.73 0.76 0.68 0.68]
# 0.7108341986846659
# Exactitud (accuracy): 0.70995670995671

# %%
graph=tree_desc(dataset1[['x','y']],dataset1['z'],['x','y'],list(dataset1['z'].unique()))
graph.write_png('dataset1.png')
Image(graph.create_png())
# Out:
# Tamaño de X_train: (551, 2)
# Tamaño de y_train: (551,)
# Tamaño de X_test: (237, 2)
# Tamaño de y_test: (237,)
# [1. 1. 1. 1. 1.]
# 1.0
# Exactitud (accuracy): 1.0

# %%
graph=tree_desc(dataset2[['x','y']],dataset2['z'],['x','y'],list(dataset2['z'].unique()))
graph.write_png('dataset2.png')
Image(graph.create_png())
# Out:
# Tamaño de X_train: (279, 2)
# Tamaño de y_train: (279,)
# Tamaño de X_test: (120, 2)
# Tamaño de y_test: (120,)
# [0.96 1.   0.91 0.98 0.98]
# 0.9677922077922079
# Exactitud (accuracy): 0.95

# %% [markdown]
# ## SVM

# %%
def  svm_f(datax,datay,avera):


    X_train, X_test, y_train, y_test = train_test_split(datax, datay, test_size=0.3,random_state=109) 

    print("Tamaño de X_train: {}\nTamaño de y_train: {}".format(X_train.shape, y_train.shape))
    print("Tamaño de X_test: {}\nTamaño de y_test: {}".format(X_test.shape, y_test.shape))

    #Crear un nuevo clasificador SVM 
    svm_class = svm.SVC(kernel='linear') # Linear Kernel

    #Se entrena ("ajusta") el modelo, usando los patrones de entrenamiento
    svm_class.fit(X_train, y_train)

    #Se obtiene el conjunt de salidas obtenidas con el modelo ajustado, según el dataset de prueba
    y_pred = svm_class.predict(X_test)

    cv_scores = cross_val_score(svm_class, X_train, y_train, cv=5)

    print (cv_scores);

    print(np.average(cv_scores))

    print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

    # Model Precision: what percentage of positive tuples are labeled as such?
    print("Precision:",metrics.precision_score(y_test, y_pred,average=avera))

    # Model Recall: what percentage of positive tuples are labelled as such?
    print("Recall:",metrics.recall_score(y_test, y_pred,average=avera))

    fpr,tpr,_r=metrics.roc_curve(y_test,y_pred)
    roc_auc = metrics.auc(fpr, tpr)
    print(roc_auc)
    metrics.plot_roc_curve(svm_class, X_test, y_test)

# %%
svm_f(diabetes[['Embarazos', 'Glucosa', 'Presion Arterial', 'Grosor Piel', 'Insulina',
       'Indice Masa Corporal', 'Función de Pedigree', 'Edad']],diabetes.Etiqueta,'binary')
# Out:
# Tamaño de X_train: (536, 8)
# Tamaño de y_train: (536,)
# Tamaño de X_test: (231, 8)
# Tamaño de y_test: (231,)
# [0.73 0.79 0.77 0.73 0.85]
# 0.7724645205953616
# Accuracy: 0.7835497835497836
# Precision: 0.7230769230769231
# Recall: 0.5949367088607594
# 0.7382578281145903

# %%
svm_f(iris[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']],iris['Species'], 'micro')
# Out:
# Tamaño de X_train: (105, 4)
# Tamaño de y_train: (105,)
# Tamaño de X_test: (45, 4)
# Tamaño de y_test: (45,)
# [1. 1. 1. 1. 1.]
# 1.0
# Accuracy: 0.9555555555555556
# Precision: 0.9555555555555556
# Recall: 0.9555555555555556
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-280e5aaa7697> in <module>
# ----> 1 svm_f(iris[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']],iris['Species'], 'micro')
#
# <ipython-input-45-6d05df6df71c> in svm_f(datax, datay, avera)
#      30     print("Recall:",metrics.recall_score(y_test, y_pred,average=avera))
#      31
# ---> 32     fpr,tpr,_r=metrics.roc_curve(y_test,y_pred)
#      33     roc_auc = metrics.auc(fpr, tpr)
#      34     print(roc_auc)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
# ...

# %%
svm_f(dataset2[['x','y']],dataset2['z'])
# Out:
# Tamaño de X_train: (279, 2)
# Tamaño de y_train: (279,)
# Tamaño de X_test: (120, 2)
# Tamaño de y_test: (120,)
# [0.88 0.86 0.82 0.88 0.85]
# 0.8566233766233766
# Accuracy: 0.9166666666666666
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-47b13132962b> in <module>
# ----> 1 svm_f(dataset2[['x','y']],dataset2['z'])
#
# <ipython-input-32-019ff25a8cbb> in svm_f(datax, datay)
#      25
#      26     # Model Precision: what percentage of positive tuples are labeled as such?
# ---> 27     print("Precision:",metrics.precision_score(y_test, y_pred))
#      28
#      29     # Model Recall: what percentage of positive tuples are labelled as such?
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ...

# %%
# def  svm_f(datax,datay,class_n,class_n_2):


X_train, X_test, y_train, y_test = train_test_split(diabetes[['Embarazos', 'Glucosa', 'Presion Arterial', 'Grosor Piel', 'Insulina',
       'Indice Masa Corporal', 'Función de Pedigree', 'Edad']], diabetes['Etiqueta'], test_size=0.3,random_state=109) 

print("Tamaño de X_train: {}\nTamaño de y_train: {}".format(X_train.shape, y_train.shape))
print("Tamaño de X_test: {}\nTamaño de y_test: {}".format(X_test.shape, y_test.shape))

#Crear un nuevo clasificador SVM 
svm_class = svm.SVC(kernel='linear') # Linear Kernel

#Se entrena ("ajusta") el modelo, usando los patrones de entrenamiento
svm_class.fit(X_train, y_train)

#Se obtiene el conjunt de salidas obtenidas con el modelo ajustado, según el dataset de prueba
y_pred = svm_class.predict(X_test)

cv_scores = cross_val_score(svm_class, X_train, y_train, cv=5)

print (cv_scores);

print(np.average(cv_scores))

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# Model Precision: what percentage of positive tuples are labeled as such?
print("Precision:",metrics.precision_score(y_test, y_pred))

# Model Recall: what percentage of positive tuples are labelled as such?
print("Recall:",metrics.recall_score(y_test, y_pred))

fpr,tpr,_r=metrics.roc_curve(y_test,y_pred)
roc_auc = metrics.auc(fpr, tpr)
print(roc_auc)
metrics.plot_roc_curve(svm_class, X_test, y_test)
