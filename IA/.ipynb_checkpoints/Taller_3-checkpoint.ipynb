# %% [markdown]
# # **Taller 3**
#
# ## **Inteligencia Artificial**
#
# ### **Maestría en Analítica de Datos**
#
# **Facultad de Ingeniería y Ciencias Básicas.**
#
# **Universidad Central**
#
# > **Integrantes:**
#
# >>***1. Brayan Holman Paez Perez***
#
# >>***2. Michel Esteven Céspedes Medina***
#
#
# > **Profesor:**
#
# >>***Hugo Franco***

# %% [markdown]
# ## **1.  Crear una API que permita crear las estructuras de datos requeridas para la solución de problemas de búsqueda no-informada e informada.**

# %% [markdown]
# ## **2.Obtener la solución (secuencia de transiciones) del puzzle de 8 casillas mediante búsqueda noinformada:**
# ### **a. Búsqueda «primero en profundidad» (DFS).**
# ### **b. Búsqueda en profundidad limitada (DLS).**
# ### **c. Búsqueda en profundidad iterada ID-DLS.**
# ### **d. Búsqueda en anchura (visto en la clase práctica, modificado para reportar la ruta -secuencia de transiciones- obtenida).**

# %% [markdown]
# ## **3. Según el grafo especificado, implementar la búsqueda de costo uniforme para encontrar la ruta de menor coste entre Brest y:**
#
# >### **a. Grenoble.**
#
# >### **b. Estrasburgo.**
#
# >### **c. Marsella.**

# %%
class StateGraph:
    def __init__(self,structure=None,node_content=None):
        if structure is None:
            self.structure={}
        else:
            self.structure=structure
        if node_content is None:
            self.node_content={}
        else:
            self.node_content=node_content

    def getNodes(self):
        keys=list(self.structure.keys())
        node_content={}
        for key in keys:
            node_content[key]=self.node_content[key]
        return node_content
    
    def getNode(self,key):
        return self.node_content[key]
    
    def getEdges(self):
        edges=[]
        for node_key in self.structure.keys():
            for neighbour_node in self.structure[node_key]:
                if [node_key,neighbour_node] not in edges:
                    edges.append([node_key, neighbour_node])
        return edges     
    
    def getEdge(self,key):
        return self.structure[key]

# %%
grafo_estados= {
    'Brest':      (0,False),
    'Rennes':     (0,False),
    'Caen' :      (0,False),
    'Nantes':     (0,False),
    'Paris' :     (0,False),
    'Calais' :    (0,False),
    'Nancy' :     (0,False),
    'Strasbourg': (0,False),
    'Dijon':      (0,False),
    'Limoges':    (0,False),
    'Lyon':       (0,False),
    'Bordeaux':   (0,False),
    'Toulouse':   (0,False),
    'Montpellier':(0,False),
    'Avignon':    (0,False),
    'Grenoble':   (0,False),
    'Marseille':  (0,False),
    'Nice':       (0,False)
}   


grafo_estructura = {
    "Calais" : [("Caen",120), ("Paris",297), ("Nancy",534)], 
    "Caen" : [("Calais",120), ("Paris",241), ("Rennes",176)], 
    "Rennes" : [("Caen",176), ("Nantes",107), ("Brest",244),("Paris",348)], 
    "Nantes" : [("Rennes",107), ("Limoges",329), ("Bordeaux",329)], 
    "Paris" : [("Calais",297), ("Caen",241), ("Rennes",348), ("Limoges",396), ("Dijon",313), ("Nancy",372)], 
    "Dijon" : [("Lyon",192), ("Strasbourg",335), ("Nancy",201),("Paris",313)], 
    "Nancy" : [("Dijon",201), ("Strasbourg",145), ("Calais",534),("Paris",372)], 
    "Strasbourg" : [("Dijon",335), ("Nancy",145)], 
    'Limoges'    : [('Nantes',329),('Paris',396),('Lyon',389),('Bordeaux', 220),('Toulouse', 313)],
    'Bordeaux'   : [('Nantes',329),('Limoges', 220),('Toulouse', 253)],
    'Toulouse'   : [('Bordeaux',253),('Limoges',313),('Montpellier', 240)],
    'Montpellier': [('Toulouse', 240), ('Avignon', 121)],
    'Lyon'       : [('Dijon', 192), ('Limoges', 389), ('Grenoble', 104), ('Avignon', 216)],
    'Grenoble'   : [('Lyon', 104), ('Avignon', 227)],
    'Avignon'    : [('Lyon', 216), ('Grenoble', 227), ('Montpellier', 121),('Marseille',99)],
    'Marseille'  : [('Avignon', 99), ('Nice', 188)],
    'Nice'       :  [('Marseille',188)],
    'Brest'       :  [('Rennes',244)]
   


}



grafo=StateGraph(grafo_estructura,grafo_estados)

# %%
from queue import PriorityQueue ## Se usa una cola de prioridad

## Búsqueda de costo uniforme  (función externa)
def UniformCostSearch (graph, root_label,end_label):
    print ("Nodo de partida:",root_label)
    print ("Nodo de llegada:",end_label)
    grafo.node_content[end_label]=(0,True)
    if graph.getNodes() is None:
        return False
    else:
        node=graph.getNode(root_label)
        if node is None:
            return False
    
    visited_nodes=set()
    pq=PriorityQueue() #La estructura de datos principal, para priorizar los recorridos de menor coste
    pq.put((node[0],root_label,node[1])) # Se crea una cola de prioridad ad hoc con tuplas: (0: costo, 1: etiqueta_estado, 2: es_exito)
    
    iteration=0
    iterate=True
    while iterate:
        if pq.empty():
            return_value="Error"
            iterate=False
            #break #sale del bucle de evaluación
        
        t=pq.get() # En el primer paso, es el nodo raíz, luego será la tupla con menor costo
        print ("Nodo actual:", t[1], "-Lista de nodos visitados:", visited_nodes)
        

        if t[2] == True: # prueba de éxito
            print ("Estado objetivo encontrado")
            return_value=t
            lista=visited_nodes
            iterate=False
            
            
            #break #sale del bucle de evaluación
        else:
            visited_nodes.add(t[1]) # si la tupla t no corresponde al estado solución (llegada) se agrega la etiqueta "t[1]" a la lista de visitados
           
            for neighbour in graph.getEdge(t[1]): # el vecino tiene la misma estructura de un nodo del grafo (entrada de diccionario), se toma el nodo con clave "t[1]"
                
                if neighbour[0] not in visited_nodes: # Se revisa que la etiqueta del nodo vecino no esté en la lista de visitados
                    neighbour_cost=t[0]+neighbour[1]
                    pq.put((neighbour_cost,neighbour[0],graph.getNodes()[neighbour[0]][1]))
                    print ("-Iteración: ",iteration)
                    print ("-Origen: ",t[1],"-Visito:",neighbour[0], "-Costo:", neighbour_cost,"-¿Es solución? ",graph.getNode(neighbour[0])[1])
                                        
            iteration=iteration+1
    return return_value

# %% [markdown]
# result=UniformCostSearch(grafo,"Brest","Grenoble")
# print(result)

# %%
result=UniformCostSearch(grafo, "Brest","Strasbourg")
print(result)
# Out:
# Nodo de partida: Brest
# Nodo de llegada: Strasbourg
# Nodo actual: Brest -Lista de nodos visitados: set()
# -Iteración:  0
# -Origen:  Brest -Visito: Rennes -Costo: 244 -¿Es solución?  False
# Nodo actual: Rennes -Lista de nodos visitados: {'Brest'}
# -Iteración:  1
# -Origen:  Rennes -Visito: Caen -Costo: 420 -¿Es solución?  False
# -Iteración:  1
# -Origen:  Rennes -Visito: Nantes -Costo: 351 -¿Es solución?  False
# -Iteración:  1
# -Origen:  Rennes -Visito: Paris -Costo: 592 -¿Es solución?  False
# Nodo actual: Nantes -Lista de nodos visitados: {'Brest', 'Rennes'}
# -Iteración:  2
# -Origen:  Nantes -Visito: Limoges -Costo: 680 -¿Es solución?  False
# -Iteración:  2
# -Origen:  Nantes -Visito: Bordeaux -Costo: 680 -¿Es solución?  False
# Nodo actual: Caen -Lista de nodos visitados: {'Brest', 'Nantes', 'Rennes'}
# -Iteración:  3
# -Origen:  Caen -Visito: Calais -Costo: 540 -¿Es solución?  False
# -Iteración:  3
# -Origen:  Caen -Visito: Paris -Costo: 661 -¿Es solución?  False
# Nodo actual: Calais -Lista de nodos visitados: {'Caen', 'Brest', 'Nantes', 'Rennes'}
# -Iteración:  4
# -Origen:  Calais -Visito: Paris -Costo: 837 -¿Es solución?  False
# -Iteración:  4
# -Origen:  Calais -Visito: Nancy -Costo: 1074 -¿Es solución?  False
# Nodo actual: Paris -Lista de nodos visitados: {'Brest', 'Calais', 'Nantes', 'Rennes', 'Caen'}
# -Iteración:  5
# -Origen:  Paris -Visito: Limoges -Costo: 988 -¿Es solución?  False
# -Iteración:  5
# -Origen:  Paris -Visito: Dijon -Costo: 905 -¿Es solución?  False
# -Iteración:  5
# -Origen:  Paris -Visito: Nancy -Costo: 964 -¿Es solución?  False
# Nodo actual: Paris -Lista de nodos visitados: {'Brest', 'Calais', 'Nantes', 'Rennes', 'Paris', 'Caen'}
# -Iteración:  6
# -Origen:  Paris -Visito: Limoges -Costo: 1057 -¿Es solución?  False
# -Iteración:  6
# -Origen:  Paris -Visito: Dijon -Costo: 974 -¿Es solución?  False
# -Iteración:  6
# -Origen:  Paris -Visito: Nancy -Costo: 1033 -¿Es solución?  False
# Nodo actual: Bordeaux -Lista de nodos visitados: {'Brest', 'Calais', 'Nantes', 'Rennes', 'Paris', 'Caen'}
# -Iteración:  7
# -Origen:  Bordeaux -Visito: Limoges -Costo: 900 -¿Es solución?  False
# -Iteración:  7
# -Origen:  Bordeaux -Visito: Toulouse -Costo: 933 -¿Es solución?  False
# Nodo actual: Limoges -Lista de nodos visitados: {'Brest', 'Calais', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Caen'}
# -Iteración:  8
# -Origen:  Limoges -Visito: Lyon -Costo: 1069 -¿Es solución?  False
# -Iteración:  8
# -Origen:  Limoges -Visito: Toulouse -Costo: 993 -¿Es solución?  False
# Nodo actual: Paris -Lista de nodos visitados: {'Brest', 'Calais', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  9
# -Origen:  Paris -Visito: Dijon -Costo: 1150 -¿Es solución?  False
# -Iteración:  9
# -Origen:  Paris -Visito: Nancy -Costo: 1209 -¿Es solución?  False
# Nodo actual: Limoges -Lista de nodos visitados: {'Brest', 'Calais', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  10
# -Origen:  Limoges -Visito: Lyon -Costo: 1289 -¿Es solución?  False
# -Iteración:  10
# -Origen:  Limoges -Visito: Toulouse -Costo: 1213 -¿Es solución?  False
# Nodo actual: Dijon -Lista de nodos visitados: {'Brest', 'Calais', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  11
# -Origen:  Dijon -Visito: Lyon -Costo: 1097 -¿Es solución?  False
# -Iteración:  11
# -Origen:  Dijon -Visito: Strasbourg -Costo: 1240 -¿Es solución?  True
# -Iteración:  11
# -Origen:  Dijon -Visito: Nancy -Costo: 1106 -¿Es solución?  False
# Nodo actual: Toulouse -Lista de nodos visitados: {'Dijon', 'Brest', 'Calais', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  12
# -Origen:  Toulouse -Visito: Montpellier -Costo: 1173 -¿Es solución?  False
# Nodo actual: Nancy -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  13
# -Origen:  Nancy -Visito: Strasbourg -Costo: 1109 -¿Es solución?  True
# Nodo actual: Dijon -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  14
# -Origen:  Dijon -Visito: Lyon -Costo: 1166 -¿Es solución?  False
# -Iteración:  14
# -Origen:  Dijon -Visito: Strasbourg -Costo: 1309 -¿Es solución?  True
# Nodo actual: Limoges -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  15
# -Origen:  Limoges -Visito: Lyon -Costo: 1377 -¿Es solución?  False
# Nodo actual: Toulouse -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  16
# -Origen:  Toulouse -Visito: Montpellier -Costo: 1233 -¿Es solución?  False
# Nodo actual: Nancy -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  17
# -Origen:  Nancy -Visito: Strasbourg -Costo: 1178 -¿Es solución?  True
# Nodo actual: Limoges -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  18
# -Origen:  Limoges -Visito: Lyon -Costo: 1446 -¿Es solución?  False
# Nodo actual: Lyon -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  19
# -Origen:  Lyon -Visito: Grenoble -Costo: 1173 -¿Es solución?  True
# -Iteración:  19
# -Origen:  Lyon -Visito: Avignon -Costo: 1285 -¿Es solución?  False
# Nodo actual: Nancy -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Lyon', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  20
# -Origen:  Nancy -Visito: Strasbourg -Costo: 1219 -¿Es solución?  True
# Nodo actual: Lyon -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Lyon', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  21
# -Origen:  Lyon -Visito: Grenoble -Costo: 1201 -¿Es solución?  True
# -Iteración:  21
# -Origen:  Lyon -Visito: Avignon -Costo: 1313 -¿Es solución?  False
# Nodo actual: Nancy -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Lyon', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  22
# -Origen:  Nancy -Visito: Strasbourg -Costo: 1251 -¿Es solución?  True
# Nodo actual: Strasbourg -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Lyon', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# Estado objetivo encontrado
# (1109, 'Strasbourg', True)

# %%
result=UniformCostSearch(grafo,"Brest", "Marseille")
print(result)
# Out:
# Nodo de partida: Brest
# Nodo de llegada: Marseille
# Nodo actual: Brest -Lista de nodos visitados: set()
# -Iteración:  0
# -Origen:  Brest -Visito: Rennes -Costo: 244 -¿Es solución?  False
# Nodo actual: Rennes -Lista de nodos visitados: {'Brest'}
# -Iteración:  1
# -Origen:  Rennes -Visito: Caen -Costo: 420 -¿Es solución?  False
# -Iteración:  1
# -Origen:  Rennes -Visito: Nantes -Costo: 351 -¿Es solución?  False
# -Iteración:  1
# -Origen:  Rennes -Visito: Paris -Costo: 592 -¿Es solución?  False
# Nodo actual: Nantes -Lista de nodos visitados: {'Brest', 'Rennes'}
# -Iteración:  2
# -Origen:  Nantes -Visito: Limoges -Costo: 680 -¿Es solución?  False
# -Iteración:  2
# -Origen:  Nantes -Visito: Bordeaux -Costo: 680 -¿Es solución?  False
# Nodo actual: Caen -Lista de nodos visitados: {'Brest', 'Nantes', 'Rennes'}
# -Iteración:  3
# -Origen:  Caen -Visito: Calais -Costo: 540 -¿Es solución?  False
# -Iteración:  3
# -Origen:  Caen -Visito: Paris -Costo: 661 -¿Es solución?  False
# Nodo actual: Calais -Lista de nodos visitados: {'Caen', 'Brest', 'Nantes', 'Rennes'}
# -Iteración:  4
# -Origen:  Calais -Visito: Paris -Costo: 837 -¿Es solución?  False
# -Iteración:  4
# -Origen:  Calais -Visito: Nancy -Costo: 1074 -¿Es solución?  False
# Nodo actual: Paris -Lista de nodos visitados: {'Brest', 'Calais', 'Nantes', 'Rennes', 'Caen'}
# -Iteración:  5
# -Origen:  Paris -Visito: Limoges -Costo: 988 -¿Es solución?  False
# -Iteración:  5
# -Origen:  Paris -Visito: Dijon -Costo: 905 -¿Es solución?  False
# -Iteración:  5
# -Origen:  Paris -Visito: Nancy -Costo: 964 -¿Es solución?  False
# Nodo actual: Paris -Lista de nodos visitados: {'Brest', 'Calais', 'Nantes', 'Rennes', 'Paris', 'Caen'}
# -Iteración:  6
# -Origen:  Paris -Visito: Limoges -Costo: 1057 -¿Es solución?  False
# -Iteración:  6
# -Origen:  Paris -Visito: Dijon -Costo: 974 -¿Es solución?  False
# -Iteración:  6
# -Origen:  Paris -Visito: Nancy -Costo: 1033 -¿Es solución?  False
# Nodo actual: Bordeaux -Lista de nodos visitados: {'Brest', 'Calais', 'Nantes', 'Rennes', 'Paris', 'Caen'}
# -Iteración:  7
# -Origen:  Bordeaux -Visito: Limoges -Costo: 900 -¿Es solución?  False
# -Iteración:  7
# -Origen:  Bordeaux -Visito: Toulouse -Costo: 933 -¿Es solución?  False
# Nodo actual: Limoges -Lista de nodos visitados: {'Brest', 'Calais', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Caen'}
# -Iteración:  8
# -Origen:  Limoges -Visito: Lyon -Costo: 1069 -¿Es solución?  False
# -Iteración:  8
# -Origen:  Limoges -Visito: Toulouse -Costo: 993 -¿Es solución?  False
# Nodo actual: Paris -Lista de nodos visitados: {'Brest', 'Calais', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  9
# -Origen:  Paris -Visito: Dijon -Costo: 1150 -¿Es solución?  False
# -Iteración:  9
# -Origen:  Paris -Visito: Nancy -Costo: 1209 -¿Es solución?  False
# Nodo actual: Limoges -Lista de nodos visitados: {'Brest', 'Calais', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  10
# -Origen:  Limoges -Visito: Lyon -Costo: 1289 -¿Es solución?  False
# -Iteración:  10
# -Origen:  Limoges -Visito: Toulouse -Costo: 1213 -¿Es solución?  False
# Nodo actual: Dijon -Lista de nodos visitados: {'Brest', 'Calais', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  11
# -Origen:  Dijon -Visito: Lyon -Costo: 1097 -¿Es solución?  False
# -Iteración:  11
# -Origen:  Dijon -Visito: Strasbourg -Costo: 1240 -¿Es solución?  False
# -Iteración:  11
# -Origen:  Dijon -Visito: Nancy -Costo: 1106 -¿Es solución?  False
# Nodo actual: Toulouse -Lista de nodos visitados: {'Dijon', 'Brest', 'Calais', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  12
# -Origen:  Toulouse -Visito: Montpellier -Costo: 1173 -¿Es solución?  False
# Nodo actual: Nancy -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  13
# -Origen:  Nancy -Visito: Strasbourg -Costo: 1109 -¿Es solución?  False
# Nodo actual: Dijon -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  14
# -Origen:  Dijon -Visito: Lyon -Costo: 1166 -¿Es solución?  False
# -Iteración:  14
# -Origen:  Dijon -Visito: Strasbourg -Costo: 1309 -¿Es solución?  False
# Nodo actual: Limoges -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  15
# -Origen:  Limoges -Visito: Lyon -Costo: 1377 -¿Es solución?  False
# Nodo actual: Toulouse -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  16
# -Origen:  Toulouse -Visito: Montpellier -Costo: 1233 -¿Es solución?  False
# Nodo actual: Nancy -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  17
# -Origen:  Nancy -Visito: Strasbourg -Costo: 1178 -¿Es solución?  False
# Nodo actual: Limoges -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  18
# -Origen:  Limoges -Visito: Lyon -Costo: 1446 -¿Es solución?  False
# Nodo actual: Lyon -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  19
# -Origen:  Lyon -Visito: Grenoble -Costo: 1173 -¿Es solución?  True
# -Iteración:  19
# -Origen:  Lyon -Visito: Avignon -Costo: 1285 -¿Es solución?  False
# Nodo actual: Nancy -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Lyon', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  20
# -Origen:  Nancy -Visito: Strasbourg -Costo: 1219 -¿Es solución?  False
# Nodo actual: Lyon -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Lyon', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  21
# -Origen:  Lyon -Visito: Grenoble -Costo: 1201 -¿Es solución?  True
# -Iteración:  21
# -Origen:  Lyon -Visito: Avignon -Costo: 1313 -¿Es solución?  False
# Nodo actual: Nancy -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Lyon', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  22
# -Origen:  Nancy -Visito: Strasbourg -Costo: 1251 -¿Es solución?  False
# Nodo actual: Strasbourg -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Lyon', 'Nantes', 'Rennes', 'Paris', 'Limoges', 'Caen'}
# Nodo actual: Dijon -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Lyon', 'Nantes', 'Rennes', 'Strasbourg', 'Paris', 'Limoges', 'Caen'}
# Nodo actual: Lyon -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Lyon', 'Nantes', 'Rennes', 'Strasbourg', 'Paris', 'Limoges', 'Caen'}
# -Iteración:  25
# -Origen:  Lyon -Visito: Grenoble -Costo: 1270 -¿Es solución?  True
# -Iteración:  25
# -Origen:  Lyon -Visito: Avignon -Costo: 1382 -¿Es solución?  False
# Nodo actual: Grenoble -Lista de nodos visitados: {'Toulouse', 'Dijon', 'Brest', 'Calais', 'Nancy', 'Bordeaux', 'Lyon', 'Nantes', 'Rennes', 'Strasbourg', 'Paris', 'Limoges', 'Caen'}
# Estado objetivo encontrado
# (1173, 'Grenoble', True)

# %%
grafo.node_content
# Out:
# {'Brest': (0, False),
#  'Rennes': (0, False),
#  'Caen': (0, False),
#  'Nantes': (0, False),
#  'Paris': (0, False),
#  'Calais': (0, False),
#  'Nancy': (0, False),
#  'Strasbourg': (0, False),
#  'Dijon': (0, False),
#  'Limoges': (0, False),
#  'Lyon': (0, False),
#  'Bordeaux': (0, False),
#  'Toulouse': (0, False),
#  'Montpellier': (0, False),
#  'Avignon': (0, False),
#  'Grenoble': (0, False),
#  'Marseille': (0, False),
#  'Nice': (0, False)}
