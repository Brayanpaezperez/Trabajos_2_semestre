# %% [markdown]
# # Datafolio

# %% [markdown]
# Para acceder a los datos que se desean analizar consulte  el siguiente [enlace.](https://datacatalog.worldbank.org/dataset/world-development-indicators) (Data & Resources)

# %%
#Importando librerías que tal vez pueda utilizar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as sm
import warnings

warnings.filterwarnings("ignore")  # Elimina las advertencias

# %% [markdown]
# El archivo `WDIData` contiene información de muchos indicadores de los países y regiones del mundo desde el año 1960, es notable que hay una gran cantidad de datos `NaN` ya que no ha sido posible recolectar la misma información en todos los países de igual manera.
#
# El documento `WDISeries` contiene información más detallada del indicador presente en el archivo `WDIData`.
#
# En la tabla `WDICountry` se muestra información relevante de cada uno de los países.

# %% [markdown]
# # Ejercicio 1
#
# Haga una lista de todos los temas ('Topic') que hay en el archivo   `WDISeries`, seleccione un sub-tema, por ejemplo, el tema general puede ser 'Environment' y el sub-tema 'Land use' y agregue una columna a `WDISeries` cuyo valor sea el sub-tema elegido, si no es del sub-tema elegido ponga el valor `NaN`.

# %%
# Subtema=
dfs=pd.read_csv('WDISeries.csv')
dfs['Subtema']=np.where(dfs['Topic']=='Infrastructure: Communications', 'Infrastructure: Communications' ,None)
dfs
# Out:
#             Series Code                                 Topic  \
# 0        AG.AGR.TRAC.NO  Environment: Agricultural production
# 1     AG.CON.FERT.PT.ZS  Environment: Agricultural production
# 2        AG.CON.FERT.ZS  Environment: Agricultural production
# 3        AG.LND.AGRI.K2                 Environment: Land use
# 4        AG.LND.AGRI.ZS                 Environment: Land use
# ...                 ...                                   ...
# 1429        VC.IDP.NWDS   Public Sector: Conflict & fragility
# 1430        VC.IDP.TOCV   Public Sector: Conflict & fragility
# 1431  VC.IHR.PSRC.FE.P5   Public Sector: Conflict & fragility
# 1432  VC.IHR.PSRC.MA.P5   Public Sector: Conflict & fragility
# 1433     VC.IHR.PSRC.P5   Public Sector: Conflict & fragility
#
#                                          Indicator Name Short definition  \
# 0                      Agricultural machinery, tractors              NaN
# 1     Fertilizer consumption (% of fertilizer produc...              NaN
# 2     Fertilizer consumption (kilograms per hectare ...              NaN
# 3                            Agricultural land (sq. km)              NaN
# 4                    Agricultural land (% of land area)              NaN
# ...                                                 ...              ...
# 1429  Internally displaced persons, new displacement...              NaN
# 1430  Internally displaced persons, total displaced ...              NaN
# 1431  Intentional homicides, female (per 100,000 fem...              NaN
# 1432     Intentional homicides, male (per 100,000 male)              NaN
# 1433         Intentional homicides (per 100,000 people)              NaN
#
#                                         Long definition Unit of measure  \
# 0     Agricultural machinery refers to the number of...             NaN
# 1     Fertilizer consumption measures the quantity o...             NaN
# 2     Fertilizer consumption measures the quantity o...             NaN
# 3     Agricultural land refers to the share of land ...             NaN
# 4     Agricultural land refers to the share of land ...             NaN
# ...                                                 ...             ...
# 1429  Internally displaced persons are defined accor...             NaN
# 1430  Internally displaced persons are defined accor...             NaN
# 1431  Intentional homicides, female are estimates of...             NaN
# 1432  Intentional homicides, male are estimates of u...             NaN
# 1433  Intentional homicides are estimates of unlawfu...             NaN
#
#      Periodicity Base Period Other notes Aggregation method  ...  \
# 0         Annual         NaN         NaN                Sum  ...
# 1         Annual         NaN         NaN   Weighted average  ...
# 2         Annual         NaN         NaN   Weighted average  ...
# 3         Annual         NaN         NaN                Sum  ...
# 4         Annual         NaN         NaN   Weighted average  ...
# ...          ...         ...         ...                ...  ...
# 1429      Annual         NaN         NaN                Sum  ...
# 1430      Annual         NaN         NaN                Sum  ...
# 1431      Annual         NaN         NaN                NaN  ...
# 1432      Annual         NaN         NaN                NaN  ...
# 1433      Annual         NaN         NaN   Weighted average  ...
#
#      General comments                                             Source  \
# 0                 NaN  Food and Agriculture Organization, electronic ...
# 1                 NaN  Food and Agriculture Organization, electronic ...
# 2                 NaN  Food and Agriculture Organization, electronic ...
# 3                 NaN  Food and Agriculture Organization, electronic ...
# 4                 NaN  Food and Agriculture Organization, electronic ...
# ...               ...                                                ...
# 1429              NaN  The Internal Displacement Monitoring Centre (h...
# 1430              NaN  The Internal Displacement Monitoring Centre (h...
# 1431              NaN  UN Office on Drugs and Crime's International H...
# 1432              NaN  UN Office on Drugs and Crime's International H...
# 1433              NaN  UN Office on Drugs and Crime's International H...
#
#                     Statistical concept and methodology  \
# 0     A tractor provides the power and traction to m...
# 1     Fertilizer consumption measures the quantity o...
# 2     Fertilizer consumption measures the quantity o...
# 3     Agricultural land constitutes only a part of a...
# 4     Agriculture is still a major sector in many ec...
# ...                                                 ...
# 1429  Internally displaced persons are "persons or g...
# 1430  Internally displaced persons are "persons or g...
# 1431  The definitions used to produce data are in li...
# 1432  The definitions used to produce data are in li...
# 1433  The definitions used to produce data are in li...
#
#                                   Development relevance Related source links  \
# 0     Agricultural land covers more than one-third o...                  NaN
# 1     Factors such as the green revolution, has led ...                  NaN
# 2     Factors such as the green revolution, has led ...                  NaN
# 3     Agricultural land covers more than one-third o...                  NaN
# 4     Agricultural land covers more than one-third o...                  NaN
# ...                                                 ...                  ...
# 1429  Although all persons affected by conflict and/...                  NaN
# 1430  Although all persons affected by conflict and/...                  NaN
# 1431  In some regions, organized crime, drug traffic...                  NaN
# 1432  In some regions, organized crime, drug traffic...                  NaN
# 1433  In some regions, organized crime, drug traffic...                  NaN
#
#      Other web links Related indicators  License Type Unnamed: 20 Subtema
# 0                NaN                NaN     CC BY-4.0         NaN    None
# 1                NaN                NaN     CC BY-4.0         NaN    None
# 2                NaN                NaN     CC BY-4.0         NaN    None
# 3                NaN                NaN     CC BY-4.0         NaN    None
# 4                NaN                NaN     CC BY-4.0         NaN    None
# ...              ...                ...           ...         ...     ...
# 1429             NaN                NaN     CC BY-4.0         NaN    None
# 1430             NaN                NaN     CC BY-4.0         NaN    None
# 1431             NaN                NaN     CC BY-4.0         NaN    None
# 1432             NaN                NaN     CC BY-4.0         NaN    None
# 1433             NaN                NaN     CC BY-4.0         NaN    None
#
# [1434 rows x 22 columns]

# %% [markdown]
# # Ejercicio 2
# Cree una nueva base de datos que contenga el histórico de todos los sucesos de su sub-tema por países y regiones. Llámela `sub-tema_df`. Trate esta nueva base de datos para que sea más legible y limpie, de ser necesario, la base.

# %%
df_WDI_Data=pd.read_csv('WDIData.csv')
df_WDI_Data=df_WDI_Data.drop('Unnamed: 65', axis=1)
lista_columns=df_WDI_Data.columns
lista_columns_titles=lista_columns[0:4]
lista_columns_unpivot= lista_columns[4:]
df_unpivot=pd.melt(df_WDI_Data, id_vars=lista_columns_titles, value_vars=lista_columns_unpivot, var_name='Año', value_name='Valor')
df_unpivot=df_unpivot[df_unpivot.Valor.notna()]

# %%
sub_tema_df=dfs[dfs.Subtema.notna()]

sub_tema_df=df_unpivot.merge(sub_tema_df,left_on='Indicator Code', right_on='Series Code')
dfcountry_series=pd.read_csv('WDICountry.csv')
sub_tema_df=sub_tema_df.merge(dfcountry_series,left_on='Country Code', right_on='Country Code')
sub_tema_df=sub_tema_df.drop(['Short definition','Unit of measure','Base Period','Other notes','Notes from original source','Related source links','Other web links'
                             ,'Related indicators','Unnamed: 20','PPP survey year','Unnamed: 30'], axis=1)
sub_tema_df
# Out:
#                    Country Name Country Code               Indicator Name_x  \
# 0                    Arab World          ARB  Mobile cellular subscriptions
# 1                    Arab World          ARB  Mobile cellular subscriptions
# 2                    Arab World          ARB  Mobile cellular subscriptions
# 3                    Arab World          ARB  Mobile cellular subscriptions
# 4                    Arab World          ARB  Mobile cellular subscriptions
# ...                         ...          ...                            ...
# 90072  St. Martin (French part)          MAF        Secure Internet servers
# 90073  St. Martin (French part)          MAF        Secure Internet servers
# 90074  St. Martin (French part)          MAF        Secure Internet servers
# 90075  St. Martin (French part)          MAF        Secure Internet servers
# 90076  St. Martin (French part)          MAF        Secure Internet servers
#
#       Indicator Code   Año  Valor  Series Code  \
# 0        IT.CEL.SETS  1960    0.0  IT.CEL.SETS
# 1        IT.CEL.SETS  1965    0.0  IT.CEL.SETS
# 2        IT.CEL.SETS  1970    0.0  IT.CEL.SETS
# 3        IT.CEL.SETS  1975    0.0  IT.CEL.SETS
# 4        IT.CEL.SETS  1976    0.0  IT.CEL.SETS
# ...              ...   ...    ...          ...
# 90072    IT.NET.SECR  2015    4.0  IT.NET.SECR
# 90073    IT.NET.SECR  2016   12.0  IT.NET.SECR
# 90074    IT.NET.SECR  2017    9.0  IT.NET.SECR
# 90075    IT.NET.SECR  2018   11.0  IT.NET.SECR
# 90076    IT.NET.SECR  2020   15.0  IT.NET.SECR
#
#                                 Topic               Indicator Name_y  \
# 0      Infrastructure: Communications  Mobile cellular subscriptions
# 1      Infrastructure: Communications  Mobile cellular subscriptions
# 2      Infrastructure: Communications  Mobile cellular subscriptions
# 3      Infrastructure: Communications  Mobile cellular subscriptions
# 4      Infrastructure: Communications  Mobile cellular subscriptions
# ...                               ...                            ...
# 90072  Infrastructure: Communications        Secure Internet servers
# 90073  Infrastructure: Communications        Secure Internet servers
# 90074  Infrastructure: Communications        Secure Internet servers
# 90075  Infrastructure: Communications        Secure Internet servers
# 90076  Infrastructure: Communications        Secure Internet servers
#
#                                          Long definition  ... System of trade  \
# 0      Mobile cellular telephone subscriptions are su...  ...             NaN
# 1      Mobile cellular telephone subscriptions are su...  ...             NaN
# 2      Mobile cellular telephone subscriptions are su...  ...             NaN
# 3      Mobile cellular telephone subscriptions are su...  ...             NaN
# 4      Mobile cellular telephone subscriptions are su...  ...             NaN
# ...                                                  ...  ...             ...
# 90072  The number of distinct, publicly-trusted TLS/S...  ...             NaN
# 90073  The number of distinct, publicly-trusted TLS/S...  ...             NaN
# 90074  The number of distinct, publicly-trusted TLS/S...  ...             NaN
# 90075  The number of distinct, publicly-trusted TLS/S...  ...             NaN
# 90076  The number of distinct, publicly-trusted TLS/S...  ...             NaN
#
#       Government Accounting concept IMF data dissemination standard  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
# ...                             ...                             ...
# 90072                           NaN                             NaN
# 90073                           NaN                             NaN
# 90074                           NaN                             NaN
# 90075                           NaN                             NaN
# 90076                           NaN                             NaN
#
#       Latest population census Latest household survey  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# ...                        ...                     ...
# 90072                     2015                     NaN
# 90073                     2015                     NaN
# 90074                     2015                     NaN
# 90075                     2015                     NaN
# 90076                     2015                     NaN
#
#       Source of most recent Income and expenditure data  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 90072                                               NaN
# 90073                                               NaN
# 90074                                               NaN
# 90075                                               NaN
# 90076                                               NaN
#
#       Vital registration complete Latest agricultural census  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 90072                         Yes                        NaN
# 90073                         Yes                        NaN
# 90074                         Yes                        NaN
# 90075                         Yes                        NaN
# 90076                         Yes                        NaN
#
#       Latest industrial data Latest trade data
# 0                        NaN            2016.0
# 1                        NaN            2016.0
# 2                        NaN            2016.0
# 3                        NaN            2016.0
# 4                        NaN            2016.0
# ...                      ...               ...
# 90072                    NaN            2015.0
# 90073                    NaN            2015.0
# 90074                    NaN            2015.0
# 90075                    NaN            2015.0
# 90076                    NaN            2015.0
#
# [90077 rows x 47 columns]

# %% [markdown]
# # Ejercicio 3
# Divida la base de datos resultante del ejercicio anterior en dos, `sub-tema_C_df` y `sub-tema_R_df`, la primera tendrá la información por países y la segunda por regiones.
#
# *Ayuda:* Use el archivo `WDICountry`para hacer la separación adecuada, la columna 'Regions' será de gran utilidad.

# %%
sub_tema_df.columns
sub_tema_df['Indicator Name_x'].unique()
# sub-tema_C_df=sub_tema_df
# Out:
# array(['Mobile cellular subscriptions',
#        'Mobile cellular subscriptions (per 100 people)',
#        'Fixed telephone subscriptions',
#        'Fixed telephone subscriptions (per 100 people)',
#        'Individuals using the Internet (% of population)',
#        'ICT service exports (% of service exports, BoP)',
#        'ICT service exports (BoP, current US$)',
#        'Fixed broadband subscriptions',
#        'Fixed broadband subscriptions (per 100 people)',
#        'ICT goods exports (% of total goods exports)',
#        'ICT goods imports (% total goods imports)',
#        'Secure Internet servers (per 1 million people)',
#        'Secure Internet servers'], dtype=object)

# %% [markdown]
# # Ejercicio 4
# La base de datos aún conserva valores un poco difíciles de leer, remplace los valores de la columna 'Indicator code' por una descripción un poco más amena para el lector.

# %%
# indicator Name
sub_tema_df
# Out:
#                    Country Name Country Code               Indicator Name_x  \
# 0                    Arab World          ARB  Mobile cellular subscriptions
# 1                    Arab World          ARB  Mobile cellular subscriptions
# 2                    Arab World          ARB  Mobile cellular subscriptions
# 3                    Arab World          ARB  Mobile cellular subscriptions
# 4                    Arab World          ARB  Mobile cellular subscriptions
# ...                         ...          ...                            ...
# 90072  St. Martin (French part)          MAF        Secure Internet servers
# 90073  St. Martin (French part)          MAF        Secure Internet servers
# 90074  St. Martin (French part)          MAF        Secure Internet servers
# 90075  St. Martin (French part)          MAF        Secure Internet servers
# 90076  St. Martin (French part)          MAF        Secure Internet servers
#
#       Indicator Code   Año  Valor  Series Code  \
# 0        IT.CEL.SETS  1960    0.0  IT.CEL.SETS
# 1        IT.CEL.SETS  1965    0.0  IT.CEL.SETS
# 2        IT.CEL.SETS  1970    0.0  IT.CEL.SETS
# 3        IT.CEL.SETS  1975    0.0  IT.CEL.SETS
# 4        IT.CEL.SETS  1976    0.0  IT.CEL.SETS
# ...              ...   ...    ...          ...
# 90072    IT.NET.SECR  2015    4.0  IT.NET.SECR
# 90073    IT.NET.SECR  2016   12.0  IT.NET.SECR
# 90074    IT.NET.SECR  2017    9.0  IT.NET.SECR
# 90075    IT.NET.SECR  2018   11.0  IT.NET.SECR
# 90076    IT.NET.SECR  2020   15.0  IT.NET.SECR
#
#                                 Topic               Indicator Name_y  \
# 0      Infrastructure: Communications  Mobile cellular subscriptions
# 1      Infrastructure: Communications  Mobile cellular subscriptions
# 2      Infrastructure: Communications  Mobile cellular subscriptions
# 3      Infrastructure: Communications  Mobile cellular subscriptions
# 4      Infrastructure: Communications  Mobile cellular subscriptions
# ...                               ...                            ...
# 90072  Infrastructure: Communications        Secure Internet servers
# 90073  Infrastructure: Communications        Secure Internet servers
# 90074  Infrastructure: Communications        Secure Internet servers
# 90075  Infrastructure: Communications        Secure Internet servers
# 90076  Infrastructure: Communications        Secure Internet servers
#
#                                          Long definition  ... System of trade  \
# 0      Mobile cellular telephone subscriptions are su...  ...             NaN
# 1      Mobile cellular telephone subscriptions are su...  ...             NaN
# 2      Mobile cellular telephone subscriptions are su...  ...             NaN
# 3      Mobile cellular telephone subscriptions are su...  ...             NaN
# 4      Mobile cellular telephone subscriptions are su...  ...             NaN
# ...                                                  ...  ...             ...
# 90072  The number of distinct, publicly-trusted TLS/S...  ...             NaN
# 90073  The number of distinct, publicly-trusted TLS/S...  ...             NaN
# 90074  The number of distinct, publicly-trusted TLS/S...  ...             NaN
# 90075  The number of distinct, publicly-trusted TLS/S...  ...             NaN
# 90076  The number of distinct, publicly-trusted TLS/S...  ...             NaN
#
#       Government Accounting concept IMF data dissemination standard  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
# ...                             ...                             ...
# 90072                           NaN                             NaN
# 90073                           NaN                             NaN
# 90074                           NaN                             NaN
# 90075                           NaN                             NaN
# 90076                           NaN                             NaN
#
#       Latest population census Latest household survey  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# ...                        ...                     ...
# 90072                     2015                     NaN
# 90073                     2015                     NaN
# 90074                     2015                     NaN
# 90075                     2015                     NaN
# 90076                     2015                     NaN
#
#       Source of most recent Income and expenditure data  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 90072                                               NaN
# 90073                                               NaN
# 90074                                               NaN
# 90075                                               NaN
# 90076                                               NaN
#
#       Vital registration complete Latest agricultural census  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 90072                         Yes                        NaN
# 90073                         Yes                        NaN
# 90074                         Yes                        NaN
# 90075                         Yes                        NaN
# 90076                         Yes                        NaN
#
#       Latest industrial data Latest trade data
# 0                        NaN            2016.0
# 1                        NaN            2016.0
# 2                        NaN            2016.0
# 3                        NaN            2016.0
# 4                        NaN            2016.0
# ...                      ...               ...
# 90072                    NaN            2015.0
# 90073                    NaN            2015.0
# 90074                    NaN            2015.0
# 90075                    NaN            2015.0
# 90076                    NaN            2015.0
#
# [90077 rows x 47 columns]

# %% [markdown]
# # Ejercicio 5
# Es aquí donde su creatividad será puesta a prueba, pues ya tiene una base de datos en buenas condiciones para representar gráficamente muchísima información, pero no se cohiba, si quiere puede agregar más columnas de los demás archivos para hacer más y graficos más específicos.
#
# *Sugerencia:* Grafique la distribución de las variables obtenidas, el comparativo entre regiones, como también entre los países que más aportan, las diferencias entre los países con ingresos altos medios y bajos, no se le sugiere más porque usted debe ser el creativo.
#
# Recuerde la información debe ser relevante, fácil de leer y puede emplear las diferentes librerías vistas hasta ahora para hacer de su datafolio el mejor.

# %%
def grafica_año(dataframe,tema):
    sub_tema_df_cel=dataframe
    sub_tema_df_cel=sub_tema_df[sub_tema_df['Indicator Name_x']==tema]
    df_indi_año=sub_tema_df_cel.groupby(['Año'])['Valor'].sum().astype('int64').reset_index(name='Total')
    df_indi_año['Año']=(df_indi_año['Año'].astype(int))
    df_indi_año['Año_1']=df_indi_año['Año'].astype(int)+1
    df_indi_año=df_indi_año[['Año','Total']].merge(df_indi_año[['Año_1','Total']],left_on='Año',right_on='Año_1')
    df_indi_año=df_indi_año[['Año','Total_x','Total_y']]
    df_indi_año['Percent']=((df_indi_año['Total_x']/df_indi_año['Total_y'] -1)*100).astype(float).round(1)
    df_indi_año=df_indi_año[df_indi_año.Percent.notna()]
    df_indi_año['Año']=df_indi_año['Año'].astype(str)
    plt.figure(figsize=(40,20))
    vals=df_indi_año['Año'].tolist()
    hist=df_indi_año['Percent'].tolist()
    plt.bar(vals, hist)
    plt.plot(vals, hist,'k',marker='o')
    plt.grid(True)
    for i in range(len(vals)):
      porcentaje=str(hist[i])+'%'
      plt.text(vals[i], 
             hist[i], 
             f'{porcentaje}',
             horizontalalignment='center',
             bbox=dict(facecolor='yellow', alpha=0.7),
             fontsize=8,
             color = 'blue',
             fontweight = 'bold')
    
    plt.show()

def grafica_region(dataframe,tema):
    sub_tema_df_cel=dataframe
    sub_tema_df_cel=sub_tema_df[sub_tema_df['Indicator Name_x']==tema]
    df_indi_año=sub_tema_df_cel.groupby(['Region'])['Valor'].sum().astype('int64').reset_index(name='Total')
    plt.figure(figsize=(40,20))
    vals=df_indi_año['Region'].tolist()
    hist=df_indi_año['Total'].tolist()
    plt.bar(vals, hist)
    plt.plot(vals, hist,'k',marker='o')
    plt.grid(True)
    for i in range(len(vals)):
      porcentaje=str(hist[i])
      plt.text(vals[i], 
             hist[i], 
             f'{porcentaje}',
             horizontalalignment='center',
             bbox=dict(facecolor='yellow', alpha=0.7),
             fontsize=12,
             color = 'blue',
             fontweight = 'bold')
    
    plt.show()

# %%
grafica_region(sub_tema_df,'Mobile cellular subscriptions (per 100 people)')

# %%
sub_tema_df_cel=sub_tema_df[sub_tema_df['Indicator Name_x']=='Mobile cellular subscriptions']
df_indi_año=sub_tema_df_cel.groupby(['Country Name','año','Income Group'])['Valor'].sum().astype('int64').reset_index(name='Total')
df_indi_año['Income Group'].unique()
# Out:
# array(['Low income', 'Upper middle income', 'Lower middle income',
#        'High income'], dtype=object)

# %% [markdown]
# # Observaciones:
# El datafolio debe:
# ```
# - Enfatizar la narración y visualización de datos sobre la explicación con mucho texto.
# - Ser de fácil lectura para la audiencia  y debe dar a entender rápidamente la esencia del trabajo.
# - Ser atractivo y accesible para audiencias 'no técnicas'.
# ```
